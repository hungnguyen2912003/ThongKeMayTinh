# %%
#####################################################
# Xây dựng Histogram
#Cách 1:
import pandas as pd
dframe=pd.DataFrame({
    'length' : [1.5,0.5,1.2,0.9,3],
    'width': [0.7,0.2,0.15,0.2,1.1]
}, index=['pig','rabbit','duck','chicken','horse'])
hist=dframe.hist(bins=3)

# %%
#Cách 2
import matplotlib.pyplot as plt
import numpy as np
d = np.random.uniform(0, 40, 100)
#n: danh sách số lượng phần tử trong mỗi bin
#bins: Mảng chứa các giá trị biên của mỗi bin
#patches: Đối tượng đại diện cho mỗi hình chữ nhật trong biểu đồ
n, bins, patches  = plt.hist(x = d, bins = 'auto', color = '#0504aa', alpha = 0.7, rwidth = 0.85)
#alpha: Độ trong suốt của các cột, 0 < alpha < 1
#rwidth: Độ rộng của các cột trong biểu đồ
#Hiển thị các đường lưới trên trục y (tần suất)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('My Very Own Histogram')
#Thêm văn bản vào biểu đồ tại toạ độ x = 23, y = 45
#$\mu=15, \sigma=3$ là công thức toán học viết dưới dạng LaTeX (ký hiệu trung bình và độ lệch chuẩn)
plt.text(23, 45, r'$\mu=15, \sigma=3$')
maxfreq=n.max()

#plt.ylim(): Giới hạn của trục y
plt.ylim(ymax=np.ceil(maxfreq/10)*10 if maxfreq % 10 else maxfreq+10)
# Out:
# (0.0, 20.0)

# %%
#Dataset 15: Old Faithful
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_excel('15_OLDFAITH.xls')
dframe = plt.hist(data['Duration'], bins='auto', color='#00BFFF', alpha = 0.7, rwidth = 0.8)
plt.title('Đồ thị histogram biểu diễn thời gian phun trào Old Faithful', fontsize=16)
plt.xlabel('Thời gian phun trào (giây)', fontsize=14)
plt.ylabel('Tần suất', fontsize=14)
# Out:
# Text(0, 0.5, 'Tần suất')

# %%
#Dataset 17: Trọng lượng của Diet Coke: biểu diễn trọng lượng (tính bằng pound) của Diet Coke từ Dataset 17
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_excel('17_COLA.xls')
dframe = plt.hist(data['CKDIETWT'], bins = 'auto', color='#F4A460', alpha = 0.7, rwidth = 0.8)
plt.title('Đồ thị histogram biểu diễn trọng lượng của Diet Coke', fontsize=16)
plt.xlabel('Trọng lượng của Diet Coke (pound)', fontsize=14)
plt.ylabel('Tần suất', fontsize=14)
# Out:
# Text(0, 0.5, 'Tần suất')

# %%
#####################################################
# Xây dựng Scatterplot
# Cách 1: Dùng DataFrame của package Pandas
import numpy as np
import pandas as pd

#Tạo DataFrame với dữ liệu chiều dài, chiều rộng và loài
dframe = pd.DataFrame([[5.1, 3.5, 0], 
                      [4.9, 3.0, 0],
                      [7.0, 3.2, 1],
                      [6.4, 3.2, 1],
                      [5.9, 3.0, 2]],
                    columns = ['length', 'width', 'species'])
ax1 = dframe.plot.scatter(x = 'length', y = 'width', c = 'DarkBlue')

# %%
# Cách 2: Dùng hàm matplotlib.pyplot.scatter
import numpy as np
import matplotlib.pyplot as plt
N = 500
x = np.random.rand(N)
y = np.random.rand(N)
colors = (0,0,0)
area = np.pi*3
plt.scatter(x,y,s=area,c=colors,alpha=0.5)
plt.title('Scatter plot pythonespot.com')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# C:\Users\bocut\AppData\Local\Temp\ipykernel_5232\3462119533.py:9: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(x,y,s=area,c=colors,alpha=0.5)

# %%
#Dataset 4: Nhựa/CO trong thuốc lá: trong Dataset 4, biểu diễn thuộc tính nhựa trong 
#thuốc lá cỡ king trên trục X và sử dụng carbon monoxide (CO) trong cùng loại
#thuốc lá cỡ king trên trục Y. Xác định mối quan hệ giữa nhựa thuốc lá và CO
#trong thuốc lá cỡ king.
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_excel('04_CIGARET.xls')
x = data['KgTar']
y = data['KgCO']
plt.scatter(x,y,color='blue')
plt.title('Biểu đồ Scatterplot biểu diễn mối quan hệ giữa KgTar và KgCO trong thuốc lá cỡ king')
plt.xlabel('Trọng lượng nhựa trong thuốc lá')
plt.ylabel('Trọng lượng CO trong thuốc lá')
plt.grid(True)

# %%
#Dataset 12: Tiêu thụ năng lượng và nhiệt độ: trong Dataset 12, sử dụng 22 giá trị trị nhiệt
#độ trung bình hàng ngày và sử dụng 22 giá trị lượng tiêu thụ năng lượng tương
#ứng (kWh). (Sử dụng nhiệt độ biểu diễn theo trục X). Dựa trên kết quả, có mối
#quan hệ giữa nhiệt độ trung bình hàng ngày và lượng năng lượng tiêu thụ hay
#không?
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_excel('12_ELECTRIC.xls')
x = data['AvTemp']
y = data['kWh']
plt.scatter(x,y,color='#FA8072')
plt.title('Biểu đồ Scatterplot biểu diễn mối quan hệ giữa nhiệt độ trung bình hằng ngày và lượng năng lượng tiêu thụ')
plt.xlabel('Nhiệt độ trung bình hằng ngày')
plt.ylabel('Lượng năng lượng tiêu thụ (kWh)')
plt.grid(True)

# %%
#########################################################
# Xây dựng Bar char 
# Cách 1:
import pandas as pd
df = pd.DataFrame({'lab': ['A','B','C'], 'val': [10,20,30]})
ax = df.plot.bar(x='lab', y = 'val', rot = 0)

# %%
speed = [0.1,17.5,40,48,52,69,88]
lifespan = [2,8,70,1.5,25,12,28]
index = ['snail', 'pig', 'elephant', 'rabbit', 'giraffe', 'coyote', 'horse']
df = pd.DataFrame({'speed': speed, 'lifespan': lifespan}, index = index)
ax = df.plot.bar(rot=0)

# %%
# Cách 2: VD1
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
objects=('Python','C++','Java','Perl','Scala','Lisp')
y_pos=np.arange(len(objects))
performance=[10,8,6,4,2,1]

plt.bar(y_pos,performance,align='center',alpha=0.5)
plt.xticks(y_pos,objects)
plt.ylabel('Usage')
plt.title('Programming language usage')
plt.show()

# %%
# Cách 2: VD2
import matplotlib.pyplot as plt
import numpy as np

#data to plot
n_groups=4
means_frank=(90,55,49,65)
means_guido=(85,62,54,20)

#create plot
fig,ax=plt.subplots()
index=np.arange(n_groups)
bar_width=0.35
opacity=0.8

rects1=plt.bar(index,means_frank,bar_width,
alpha=opacity,color='b',label='Frank')

rects2=plt.bar(index+bar_width,means_guido,bar_width,
alpha=opacity,color='r',label='Guido')

plt.xlabel('Person')
plt.ylabel('Scores')
plt.title('Scores by person')

plt.xticks(index+bar_width,('A','B','C','D'))
plt.legend()
plt.tight_layout()
plt.show()

# %%
#########################################################
# Xây dựng Pie chart
# Cách 1:
import pandas as pd

df=pd.DataFrame({'mass':[0.330,4.87,0.97,0.642],
'radius':[2439.7,6051.3,6373.1,3339.5]},
index=['Mercury','Venus','Earth','Mars'])

plot=df.plot.pie(y='mass',figsize=(5,5))

# %%
# Cách 2: VD1
import matplotlib.pyplot as plt

#data to plot

labels='Python','C++','Ruby','Java'
sizes=[215,130,245,210]
colors=['gold','yellowgreen','lightcoral','lightskyblue']
explode=(0.1,0,0,0)

#plot
plt.pie(sizes,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=True)

plt.axis('equal')

plt.show()

# %%
#Cách 2: VD2
import matplotlib.pyplot as plt
lables=['Cookies','Jellybean','Milkshake','Cheesecake']
sizes=[38.4,40.6,20.7,10.3]
colors=['yellowgreen','gold','lightskyblue','lightcoral']
patches,texts=plt.pie(sizes,colors=colors,shadow=True,startangle=90)
plt.legend(patches,lables,loc='best')

plt.axis('equal')

plt.tight_layout()

plt.show()

# %%
############################################################################
#Bài tập 1:

#Bar char
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt
college=('Public 2-Year','Public 4-Year','Private 2-Year','Private 4-Year')
y_pos=np.arange(len(college))
frequency = [36.8, 40, 1.6, 21.9]

plt.bar(y_pos,frequency,align='center',alpha=0.5)
plt.xticks(y_pos,college)
plt.xlabel('College')
plt.ylabel('Relative Frequency (%)')
plt.show()

# %%
#Bài tập 1:

#Pie chart

import matplotlib.pyplot as plt
college='Public 2-Year','Public 4-Year','Private 2-Year','Private 4-Year'
frequency=[36.8, 40, 1.6, 21.9]
colors=['gold','yellowgreen','lightcoral','lightskyblue']
explode=(0,0,0,0)

#plot
plt.pie(frequency,explode=explode,labels=college,colors=colors,autopct='%1.1f%%',shadow=True)

plt.axis('equal')

plt.show()

# %%
############################################################################
#Xây dựng bot plot
#Cách 1:

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

np.random.seed(1234)
df = pd.DataFrame(np.random.randn(10, 4),
columns=['col1', 'col2', 'col3', 'col4'])

boxplot = df.boxplot(column=['col1', 'col2', 'col3'])

plt.show()

# %%
#Cách 2
import numpy as np

import matplotlib.pyplot as plt

np.random.seed(19680801)

spread=np.random.rand(50)*100
center=np.ones(25)*50
flier_high=np.random.rand(10)*100+100
flier_low=np.random.rand(10)*-100
data=np.concatenate((spread,center,flier_high,flier_low))
fig1,ax1=plt.subplots()
ax1.set_title('Basic Plot')
ax1.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22d6df474d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22d6df47750>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x22d6df47390>],
#  'medians': [<matplotlib.lines.Line2D at 0x22d6df479d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22d6df47b10>],
#  'means': []}

# %%
#Trọng lượng của Coke thông thường và Coke ăn kiêng. Sử dụng cùng
#một tỷ lệ để xây dựng box plot đối với trọng lượng của Coke thông thường và
#Coke ăn kiêng từ Dataset 17. Sử dụng box plot để so sánh hai bộ dữ liệu.

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_excel('17_COLA.xls')

dframe = pd.DataFrame(data)

# Tạo box plot
plt.figure(figsize=(10, 6))
sns.boxplot(data=dframe[['CKREGWT', 'CKDIETWT']])
plt.xticks([0, 1], ['Coke Thông Thường', 'Coke Ăn Kiêng'])
plt.ylabel('Trọng lượng (pound)')
plt.title('So sánh Trọng lượng giữa Coke Thông Thường và Coke Ăn Kiêng')
plt.grid(True)
plt.show()

# %%
#Trọng lượng của Coke thông thường và Pepsi thông thường. Sử dụng
#cùng một tỷ lệ để xây dựng box plot cho trọng lượng của Coke thông thường và
#Pepsi thông thường từ Dataset 17. Sử dụng box plot để so sánh hai bộ dữ liệu.

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_excel('17_COLA.xls')

dframe = pd.DataFrame(data)

# Tạo box plot
plt.figure(figsize=(10, 6))
sns.boxplot(data=dframe[['CKREGWT', 'PPREGWT']])
plt.xticks([0, 1], ['Coke Thông Thường', 'Pepsi Thông Thường'])
plt.ylabel('Trọng lượng (pound)')
plt.title('So sánh Trọng lượng giữa Coke Thông Thường và Pepsi Thông Thường')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_excel('02_BODYTEMP.xlsx')

print("Nhiệt độ trung bình của cơ thể lúc 12:00 AM vào ngày 2: ", np.mean(data['DAY 2 - 12AM']), "độ F")
# Out:
# Nhiệt độ trung bình của cơ thể lúc 12:00 AM vào ngày 2:  98.19999999999999 độ F

# %%
########################################################
#QQ plot
from numpy.random import seed
from numpy.random import randn
from statsmodels.graphics.gofplots import qqplot
from matplotlib import pyplot
#seed the random number generator
seed(1)
#generate univariate observations
data=5*randn(100)+50
#q-q plot
qqplot(data,line='s')
pyplot.show()

# %%
#Old Faithful: biểu đồ QQ-plot biểu diễn thời gian (tính bằng giây) phun trào Old Faithful từ Dataset 15.
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_excel('15_OLDFAITH.xls')

# Vẽ QQ-plot
plt.figure(figsize=(10, 6))
qqplot(data['Duration'], line='s')
plt.title('Biểu mẫu QQ-Plot biểu diễn Thời gian Phun trào Old Faithful')
plt.grid(True)
plt.show()

# %%
#Chiều cao của phụ nữ: biểu đồ QQ-plot biểu diễn chiều cao của phụ nữ từ dataset 1.
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_excel('01_MHEALTH.xls')

# Vẽ QQ-plot
plt.figure(figsize=(10, 6))
qqplot(data['HT'], line='s')
plt.title('Biểu mẫu QQ-Plot biểu diễn chiều cao của phụ nữ')
plt.grid(True)
plt.show()

# %%
#Trọng lượng của Coke ăn kiêng: biểu đồ QQ-plot biểu diễn trọng lượng (tính bằng pound) của Diet Coke từ Dataset 17.

import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_excel('17_COLA.xls')

# Vẽ QQ-plot
plt.figure(figsize=(10, 6))
qqplot(data['CKDIETWT'], line='s')
plt.title('Biểu mẫu QQ-Plot biểu diễn trọng lượng (pound) của Diet Coke')
plt.grid(True)
plt.show()
